# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeGordeichik/AImusic/blob/main/Tracks_analysis_with_discogs_effnet_and_mtt_vgg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install essentia libraries with tensorflow support

# !pip install -q essentia-tensorflow

#Download model files

# !wget -q https://essentia.upf.edu/models/autotagging/msd/msd-musicnn-1.pb
# !wget -q https://essentia.upf.edu/models/autotagging/msd/msd-musicnn-1.json

# !wget -q https://essentia.upf.edu/models/autotagging/mtt/mtt-vgg-1.pb
# !wget -q https://essentia.upf.edu/models/autotagging/mtt/mtt-vgg-1.json

# !wget -q https://essentia.upf.edu/models/music-style-classification/discogs-effnet/discogs-effnet-bs64-1.json
# !wget -q https://essentia.upf.edu/models/music-style-classification/discogs-effnet/discogs-effnet-bs64-1.pb

# %%
#Import libraries
import json

from essentia.standard import MonoLoader, TensorflowPredictMusiCNN, TensorflowPredictVGGish, TensorflowPredictEffnetDiscogs
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load styles name from model metadata

with open('discogs-effnet-bs64-1.json', 'r') as json_file:
    metadata__discogs = json.load(json_file)
styles_discogs = metadata__discogs['classes']

with open('msd-musicnn-1.json', 'r') as json_file:
    metadata_msd = json.load(json_file)
styles_msd = metadata_msd['classes']

with open('mtt-vgg-1.json', 'r') as json_file:
    metadata_mtt = json.load(json_file)
styles_mtt = metadata_mtt['classes']

# %%
#Define inference function for Discogs model

def inference_discogs(audio_file, model, styles):
  #Do inference
  activations = TensorflowPredictEffnetDiscogs(graphFilename=model)(audio)
  #Calculate mean activations
  meanActivations = sum(activations)/len(activations)
  #Get indexes of top activations
  genreIndex = np.argpartition(meanActivations, -7)[-7:]
  #Print results
  for x in range (0,7):
      print("\t\t"+styles[genreIndex[x]]+":", "%.2f" % meanActivations[genreIndex[x]])

#Define inference function for MusiCNN models

def inference_musicnn(audio_file, model, styles):
  #Do inference
  activations = TensorflowPredictMusiCNN(graphFilename=model)(audio)
  #Calculate mean activations
  meanActivations = sum(activations)/len(activations)
  #Get indexes of top activations
  genreIndex = np.argpartition(meanActivations, -7)[-7:]
  #Print results
  for x in range (0,7):
      v = meanActivations[genreIndex[x]]
      print("\t\t"+styles[genreIndex[x]]+":", "%.2f" % meanActivations[genreIndex[x]])

# %%
#Tracklist
tracks = ["st1","st2","st3","st4","ai1", "ai2", "ai3", "ai4", "mb1", "mb2", "mb3", "mb4"]

for i in range (0,len(tracks)):
  #Load audio file
  audio_file = tracks[i]+'.mp3'
  audio = MonoLoader(sampleRate=16000, filename=audio_file)()
  print("song: "+tracks[i])
  print("{\n\tmodel: discogs")
  print("\t{")
  #Get discogs styles
  inference_discogs(audio_file, 'discogs-effnet-bs64-1.pb', styles_discogs)
  print("\tmodel: mtt")
  #Get musicnn mtt music properties
  inference_musicnn(audio_file, 'mtt-vgg-1.pb', styles_mtt)
  print("\t}\n}")
# Out:
# song: st1
# {
# 	model: discogs
# 	{
# 		Hip Hop---Jazzy Hip-Hop: 0.11
# 		Electronic---Ambient: 0.13
# 		Hip Hop---Trip Hop: 0.31
# 		Electronic---Trip Hop: 0.33
# 		Hip Hop---Instrumental: 0.20
# 		Electronic---Downtempo: 0.42
# 		Electronic---Hip Hop: 0.13
# 	model: mtt
# 		pop: 0.11
# 		electronic: 0.12
# 		ambient: 0.12
# 		synth: 0.15
# 		beat: 0.20
# 		slow: 0.23
# 		drums: 0.28
# 	}
# }
# song: st2
# {
# 	model: discogs
# 	{
# 		Jazz---Bossa Nova: 0.07
# 		Jazz---Smooth Jazz: 0.07
# 		Latin---Bossanova: 0.09
# 		Electronic---Future Jazz: 0.11
# 		Jazz---Contemporary Jazz: 0.08
# 		Jazz---Fusion: 0.11
# 		Electronic---Downtempo: 0.20
# 	model: mtt
# 		female: 0.12
# 		ambient: 0.13
# 		vocal: 0.15
# 		drums: 0.44
# 		slow: 0.23
# 		beat: 0.17
# 		guitar: 0.16
# 	}
# }
# song: st3
# {
# 	model: discogs
# 	{
# 		Electronic---Downtempo: 0.07
# 		Electronic---Experimental: 0.08
# 		Rock---Indie Rock: 0.08
# 		Rock---Dream Pop: 0.08
# 		Rock---Ethereal: 0.16
# 		Rock---Shoegaze: 0.11
# 		Electronic---Ambient: 0.38
# 	model: mtt
# 		new age: 0.15
# 		violin: 0.21
# 		ambient: 0.33
# 		classical: 0.32
# 		strings: 0.27
# 		slow: 0.42
# 		guitar: 0.25
# 	}
# }
# song: st4
# {
# 	model: discogs
# 	{
# 		Electronic---Drone: 0.06
# 		Electronic---Vaporwave: 0.08
# 		Electronic---Dungeon Synth: 0.08
# 		Electronic---Downtempo: 0.08
# 		Electronic---Experimental: 0.15
# 		Electronic---Ambient: 0.42
# 		Electronic---New Age: 0.09
# 	model: mtt
# 		new age: 0.12
# 		soft: 0.15
# 		ambient: 0.57
# 		synth: 0.20
# 		electronic: 0.17
# 		slow: 0.37
# 		quiet: 0.29
# 	}
# }
# song: ai1
# {
# 	model: discogs
# 	{
# 		Electronic---Leftfield: 0.06
# 		Electronic---Broken Beat: 0.06
# 		Hip Hop---Trip Hop: 0.07
# 		Electronic---Experimental: 0.08
# 		Electronic---Downtempo: 0.24
# 		Electronic---Trip Hop: 0.18
# 		Electronic---Ambient: 0.28
# 	model: mtt
# 		synth: 0.10
# 		techno: 0.11
# 		electronic: 0.13
# 		drums: 0.33
# 		ambient: 0.16
# 		slow: 0.33
# 		beat: 0.22
# 	}
# }
# song: ai2
# {
# 	model: discogs
# 	{
# 		Electronic---Illbient: 0.08
# 		Electronic---Experimental: 0.09
# 		Electronic---Breakbeat: 0.13
# 		Electronic---Jungle: 0.27
# 		Electronic---Ambient: 0.13
# 		Electronic---Downtempo: 0.11
# 		Electronic---Drum n Bass: 0.32
# 	model: mtt
# 		piano: 0.09
# 		synth: 0.13
# 		fast: 0.18
# 		drums: 0.40
# 		techno: 0.26
# 		electronic: 0.18
# 		beat: 0.23
# 	}
# }
# song: ai3
# {
# 	model: discogs
# 	{
# 		Electronic---Juke: 0.06
# 		Electronic---New Age: 0.06
# 		Electronic---Jungle: 0.07
# 		Electronic---Drum n Bass: 0.13
# 		Electronic---Experimental: 0.15
# 		Electronic---Downtempo: 0.17
# 		Electronic---Ambient: 0.31
# 	model: mtt
# 		ambient: 0.15
# 		synth: 0.19
# 		techno: 0.20
# 		electronic: 0.21
# 		slow: 0.24
# 		drums: 0.24
# 		beat: 0.28
# 	}
# }
# song: ai4
# {
# 	model: discogs
# 	{
# 		Electronic---Deep House: 0.04
# 		Electronic---Beatdown: 0.05
# 		Electronic---Experimental: 0.09
# 		Electronic---Trip Hop: 0.10
# 		Electronic---Downtempo: 0.23
# 		Electronic---Ambient: 0.39
# 		Electronic---Chillwave: 0.18
# 	model: mtt
# 		synth: 0.12
# 		quiet: 0.13
# 		ambient: 0.31
# 		female: 0.13
# 		slow: 0.34
# 		new age: 0.15
# 		soft: 0.15
# 	}
# }
# song: mb1
# {
# 	model: discogs
# 	{
# 		Jazz---Bossa Nova: 0.08
# 		Jazz---Smooth Jazz: 0.08
# 		Latin---Bossanova: 0.09
# 		Jazz---Contemporary Jazz: 0.09
# 		Electronic---Future Jazz: 0.10
# 		Jazz---Fusion: 0.13
# 		Electronic---Downtempo: 0.18
# 	model: mtt
# 		female: 0.12
# 		vocal: 0.15
# 		ambient: 0.13
# 		guitar: 0.16
# 		slow: 0.24
# 		beat: 0.17
# 		drums: 0.45
# 	}
# }
# song: mb2
# {
# 	model: discogs
# 	{
# 		Hip Hop---RnB/Swing: 0.06
# 		Hip Hop---Instrumental: 0.07
# 		Hip Hop---Jazzy Hip-Hop: 0.07
# 		Funk / Soul---Neo Soul: 0.10
# 		Electronic---Downtempo: 0.09
# 		Funk / Soul---Contemporary R&B: 0.06
# 		Electronic---Broken Beat: 0.11
# 	model: mtt
# 		synth: 0.14
# 		slow: 0.18
# 		guitar: 0.23
# 		drums: 0.31
# 		beat: 0.34
# 		electronic: 0.23
# 		techno: 0.26
# 	}
# }
# song: mb3
# {
# 	model: discogs
# 	{
# 		Rock---Atmospheric Black Metal: 0.05
# 		Electronic---Drone: 0.07
# 		Rock---Shoegaze: 0.09
# 		Electronic---New Age: 0.06
# 		Electronic---Ambient: 0.41
# 		Electronic---Experimental: 0.09
# 		Rock---Ethereal: 0.08
# 	model: mtt
# 		strings: 0.08
# 		classical: 0.12
# 		synth: 0.20
# 		electronic: 0.12
# 		new age: 0.15
# 		slow: 0.24
# 		ambient: 0.51
# 	}
# }
# song: mb4
# {
# 	model: discogs
# 	{
# 		Electronic---Synth-pop: 0.04
# 		Electronic---Synthwave: 0.04
# 		Electronic---Ambient: 0.10
# 		Electronic---Chillwave: 0.06
# 		Electronic---Experimental: 0.06
# 		Stage & Screen---Soundtrack: 0.04
# 		Electronic---Downtempo: 0.09
# 	model: mtt
# 		synth: 0.09
# 		rock: 0.10
# 		slow: 0.10
# 		electronic: 0.09
# 		ambient: 0.12
# 		drums: 0.27
# 		guitar: 0.33
# 	}
# }
